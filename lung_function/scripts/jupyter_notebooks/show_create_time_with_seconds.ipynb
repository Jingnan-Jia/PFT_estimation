# %%
import os, time, datetime
from glob import glob

# %%
direc = "/home/jjia/data/dataset/IntrA/generated/aneurysm/obj"

# %%
all_files = glob(direc + '/*fill*')

# %%
len(all_files)
# Out:
# 215

# %%
for file in all_files:
    modified = os.path.getmtime(file)
    print(file.split('/')[-1], "\tDate modified:",datetime.datetime.fromtimestamp(modified))
# Out:
# ArteryObjAN117-2_filled_img.mha 	Date modified: 2023-01-29 01:33:48
# ArteryObjAN117-5_filled_img.mha 	Date modified: 2023-01-29 01:33:49
# ArteryObjAN117-8_filled_img.mha 	Date modified: 2023-01-29 01:33:50
# ArteryObjAN121-5_filled_img.mha 	Date modified: 2023-01-29 01:33:51
# ArteryObjAN136-1_filled_img.mha 	Date modified: 2023-01-29 01:33:52
# ArteryObjAN136-2_filled_img.mha 	Date modified: 2023-01-29 01:33:53
# ArteryObjAN136-4_filled_img.mha 	Date modified: 2023-01-29 01:33:54
# ArteryObjAN136-6_filled_img.mha 	Date modified: 2023-01-29 01:33:55
# ArteryObjAN136-8_filled_img.mha 	Date modified: 2023-01-29 01:33:56
# ArteryObjAN149-4_filled_img.mha 	Date modified: 2023-01-29 01:33:57
# ArteryObjAN149-7_filled_img.mha 	Date modified: 2023-01-29 01:33:58
# ArteryObjAN149-8_filled_img.mha 	Date modified: 2023-01-29 01:33:59
# ArteryObjAN151-0_filled_img.mha 	Date modified: 2023-01-29 01:34:00
# ArteryObjAN151-3_filled_img.mha 	Date modified: 2023-01-29 01:34:01
# ...

# %%
all_files.sort(key=os.path.getctime)
